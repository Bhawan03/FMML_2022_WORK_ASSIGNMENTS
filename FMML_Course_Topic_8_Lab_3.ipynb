# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhawan03/FMML_2022_WORK_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-07 08:08:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   121MB/s    in 0.6s
#
# 2023-06-07 08:08:20 (121 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37736  1802.04987v2  The problem of rating the performance of socce...  stat
# 22521  1610.07407v5  We introduce a mixture model for censored dura...  stat
# 22373  1605.00355v1  Gaussian graphical models (GGMs) are probabili...  stat
# 20982  1706.00585v1  Existing methods for dealing with knowledge up...    cs
# 18517   1103.3949v2  Ontologies and rules are usually loosely coupl...    cs
# ...             ...                                                ...   ...
# 18075  cs/0305019v1  Thomas M. Strat has developed a decision-theor...    cs
# 32397  1503.08873v1  Many modern multiclass and multilabel problems...    cs
# 11990  1705.10819v1  We study data-driven representations for three...  stat
# 944    1604.05377v1  Customer temporal behavioral data was represen...  stat
# 11150   1410.5518v3  We consider the problem of designing locality ...  stat
#
#                                                    title  year  \
# 37736  PlayeRank: Multi-dimensional and role-aware ra...  2018
# 22521  C-mix: a high dimensional mixture model for ce...  2016
# 22373  Contrastive Structured Anomaly Detection for G...  2016
# 20982                  Exception-Based Knowledge Updates  2017
# 18517  A Goal-Directed Implementation of Query Answer...  2011
# ...                                                  ...   ...
# 18075  On rho in a Decision-Theoretic Apparatus of De...  2003
# 32397  Fast Label Embeddings for Extremely Large Outp...  2015
# 11990                                   Surface Networks  2017
# 944    Churn analysis using deep convolutional neural...  2016
# 11150  On Symmetric and Asymmetric LSHs for Inner Pro...  2014
#
#                                                 keywords
# 37736  [performance, attracting, companies, scientifi...
# 22521  [introduce, durations, likelihood, inference, ...
# 22373  [graphical, probabilistic, analyzing, conditio...
# 20982  [knowledge, depending, underlying, knowledge, ...
# 18517  [ontologies, knowledge, representation, formal...
# ...                                                  ...
# 18075  [developed, theoretic, apparatus, functions, a...
# 32397  [multiclass, multilabel, characterized, increa...
# 11990  [representations, dimensional, prevalent, repr...
# 944    [behavioral, represented, prediction, leveragi...
# 11150  [designing, sensitive, similarity, asymmetric,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37736    [performance, attracting, companies, scientifi...
# 22521    [introduce, durations, likelihood, inference, ...
# 22373    [graphical, probabilistic, analyzing, conditio...
# 20982    [knowledge, depending, underlying, knowledge, ...
# 18517    [ontologies, knowledge, representation, formal...
#                                ...
# 8094     [theoretical, contributions, dimensional, tran...
# 6418     [introduce, dynamical, sequentially, multivari...
# 25215    [identified, computational, digitised, investi...
# 11882    [extraction, dimension, reduction, efficiently...
# 32219    [programming, neurocontrol, reinforcement, obj...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8713 words.
# Out of those 4524 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9a64dc25-09ae-4b1b-8aca-88bb19c02662" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a64dc25-09ae-4b1b-8aca-88bb19c02662")) {                    Plotly.newPlot(                        "9a64dc25-09ae-4b1b-8aca-88bb19c02662",                        [{"x":["framework","principled","capturing","prominent","implement","validation","application","performance","evaluation","efficiency","experimental","analytics","dimensional","approaches","searching","pertaining","experiments","introducing","scientific","available","availability","community","significantly","flexibility","companies","improving","generated","attracting","parameterization","regression","distributions","proportional","statistical","maximization","containing","estimation","illustrated","outperforms","biomedical","expectation","likelihood","covariates","properties","parameters","applications","durations","convergence","algorithm","introduce","extensive","therefore","efficient","simulation","inference","assessing","foreground","conditional","precision","contrastive","simulated","alternating","distribution","detecting","direction","structured","anomalies","evolution","covariance","estimated","monitoring","estimating","dependencies","analyzing","structural","changepoints","procedure","graphical","variables","accurately","underlying","probabilistic","contribution","difference","significant","essential","detection","improvement","multipliers","corresponding","penalized","observations","background","perspective","depending","traditional","exceptions","formalism","seemingly","manipulating","classical","characterisation","connecting","operators","monotonic","typically","additional","development","exception","principles","semantics","equivalently","understanding","irreconcilable","foundation","importance","introduces","representation","interpretations","introduced","knowledge","extracted","performed","theoretic","specifying","combining","represented","answering","entailment","implementation","individuals","practical","resolution","formalized","ontologies","usefulness","statements","reasoning","inferences","programming","nonetheless","formalisms","algorithms","consistency","encodings","superiority","combinations","auxiliary","magnitudes","constraints","sensitive","generalized","coefficients","characteristic","preserving","competitive","extension","vocabulary","effective","different","important","pedagogical","previously","difficulty","presenting","motivated","hypothesise","acquisition","curriculum","structure","personalised","environment","ascending","interaction","representations","reinforcement","relations","augmented","relational","interpret","extensions","associated","centrality","expressed","conditioning","specifically","distinguish","numerical","categorical","characterization","resulting","probability","particular","communities","demonstrate","adjustments","empirical","capability","practitioners","separable","generalize"],"y":[519,23,33,19,64,57,241,898,259,160,380,10,188,413,34,2,597,47,45,318,31,66,267,31,9,90,166,5,7,126,126,12,161,39,57,213,20,292,16,34,51,5,211,244,437,2,115,774,323,166,159,383,82,215,20,24,91,80,7,63,14,216,73,56,96,8,55,22,69,37,78,47,60,77,1,108,56,136,72,100,156,73,56,207,72,358,127,10,111,8,78,80,62,35,165,6,23,4,6,113,5,20,30,15,101,107,122,7,30,114,6,162,1,21,78,73,382,17,115,357,127,132,44,9,96,89,40,20,130,34,130,125,9,22,28,12,130,16,137,9,8,557,51,9,35,43,23,2,155,57,74,37,21,62,125,79,27,224,746,372,5,92,58,16,54,3,41,5,330,2,121,4,90,206,135,98,38,28,22,41,118,2,35,12,163,29,88,14,31,145,166,277,19,555,1,159,48,14,15,44],"type":"bar"},{"x":["framework","principled","capturing","prominent","implement","validation","application","performance","evalu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4524,), (4524, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Applying</span> <span style=''>Part</span> <span style=''>of</span> <span style=''>Seech</span> <span style=''>Enhanced</span> <span style=''>LSA</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5813953488372093);'>Automatic</span> <span style=''>Essay</span> <span style=''>Grading</span> <br/><br/><span style=''>Latent</span> <span style=''>Semantic</span> <span style=''>Analysis</span> <span style=''>(LSA)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(0, 255, 0, 0.3016759776536313);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.542483660130719);'>Retrieval</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>bag</span> <span style=''>of</span> <span style=''>words</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.4857142857142857);'>according</span> <span style=''>to</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conception</span> <span style=''>syntax</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4583333333333333);'>representing</span> <span style=''>meaning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>sentences</span> <span style=''>Thus</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>enhancing</span> <span style=''>LSA</span> <span style=''>with</span> <span style=''>part</span> <span style=''>of</span> <span style=''>speech</span> <span style=''>(POS)</span> <span style='background-color:rgba(0, 255, 0, 0.3016759776536313);'>information</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>occurrences</span> <span style=''>appears</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>feasible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>tested</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5813953488372093);'>automatic</span> <span style=''>essay</span> <span style=''>grading</span> <span style=''>system</span> <span style=''>using</span> <span style=''>LSA</span> <span style=''>for</span> <span style=''>document</span> <span style='background-color:rgba(0, 255, 0, 0.3457943925233644);'>similarity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>on</span> <span style=''>several</span> <span style=''>POS</span> <span style=''>enhanced</span> <span style=''>LSA</span> <span style=''>models</span> <span style=''>is</span> <span style=''>reported</span> <span style=''>Our</span> <span style=''>findings</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>addition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615385);'>contextual</span> <span style='background-color:rgba(0, 255, 0, 0.3016759776536313);'>information</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>POS</span> <span style=''>tags</span> <span style=''>can</span> <span style=''>raise</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Sublinear</span> <span style=''>Time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transitions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Programs</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style=''>can</span> <span style=''>simplify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>but</span> <span style=''>only</span> <span style=''>if</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>highly</span> <span style=''>coupled</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <span style=''>and</span> <span style=''>state</span> <span style=''>space</span> <span style=''>models</span> <span style=''>still</span> <span style=''>scales</span> <span style=''>poorly</span> <span style=''>each</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>takes</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sublinear</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>(MH)</span> <span style=''>updates</span> <span style=''>to</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>programs</span> <span style=''>The</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>MH</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsampling</span> <span style=''>data</span> <span style=''>items</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>it</span> <span style=''>subsamples</span> <span style=''>edges</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamically</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>First</span> <span style=''>Order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <br/><br/><span style=''>GANs</span> <span style=''>excel</span> <span style=''>at</span> <span style=''>learning</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.30000000000000004);'>distributions</span> <span style=''>but</span> <span style=''>they</span> <span style=''>can</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generator</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>that</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>the</span> <span style=''>steepest</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prominent</span> <span style=''>examples</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>problematic</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>include</span> <span style=''>those</span> <span style=''>used</span> <span style=''>in</span> <span style=''>both</span> <span style=''>Goodfellows</span> <span style=''>original</span> <span style=''>GAN</span> <span style=''>and</span> <span style=''>the</span> <span style=''>WGAN</span> <span style=''>GP</span> <span style=''>To</span> <span style=''>formally</span> <span style=''>describe</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>derivation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.31914893617021284);'>requirements</span> <span style=''>on</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.47222222222222227);'>divergence</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determining</span> <span style=''>an</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.31914893617021284);'>requirements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>unbiased</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>updates</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>of</span> <span style=''>steepest</span> <span style=''>descent</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.47222222222222227);'>divergence</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>GANGs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Network</span> <span style=''>Games</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GAN)</span> <span style=''>have</span> <span style=''>become</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>modeling</span> <span style=''>As</span> <span style=''>GANs</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>train</span> <span style=''>much</span> <span style=''>research</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>this</span> <span style=''>However</span> <span style=''>very</span> <span style=''>little</span> <span style=''>of</span> <span style=''>this</span> <span style=''>research</span> <span style=''>has</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploited</span> <span style=''>game</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Network</span> <span style=''>Games</span> <span style=''>(GANGs)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>model</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>zero</span> <span style=''>sum</span> <span style=''>game</span> <span style=''>between</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generator</span> <span style=''>(G)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>(C)</span> <span style=''>that</span> <span style=''>use</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>The</span> <span style=''>size</span> <span style=''>of</span> <span style=''>these</span> <span style=''>games</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precludes</span> <span style=''>exact</span> <span style=''>solution</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>we</span> <span style=''>define</span> <span style=''>resource</span> <span style=''>bounded</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>(RBBRs)</span> <span style=''>and</span> <span style=''>a</span> <span style=''>resource</span> <span style=''>bounded</span> <span style=''>Nash</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Equilibrium</span> <span style=''>(RB</span> <span style=''>NE)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>such</span> <span style=''>that</span> <span style=''>neither</span> <span style=''>G</span> <span style=''>or</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07249466950959488)
# 	experimental (0.13503909026297087)
# 	knowledge (0.12686567164179105)
# 	segmentation (0.06787491115849324)
# 	architecture (0.0906183368869936)
# 	information (0.2484008528784648)
# 	different (0.26510305614783225)
# 	detection (0.12722103766879886)
# 	recognition (0.12046908315565032)
# 	convolutional (0.1318407960199005)
#
# Some Statistics words are:
# 	theoretical (0.15055387713997986)
# 	estimation (0.17069486404833836)
# 	variables (0.1445115810674723)
# 	stochastic (0.13947633434038267)
# 	statistical (0.162134944612286)
# 	distribution (0.1878147029204431)
# 	dimensional (0.18932527693857)
# 	algorithm (0.39778449144008055)
# 	regression (0.17623363544813697)
# 	inference (0.2094662638469285)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ae1467f1-68d7-49e8-94a6-80f6ed7489f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae1467f1-68d7-49e8-94a6-80f6ed7489f2")) {                    Plotly.newPlot(                        "ae1467f1-68d7-49e8-94a6-80f6ed7489f2",                        [{"x":["framework","principled","capturing","prominent","implement","validation","application","performance","evaluation","efficiency","experimental","analytics","dimensional","approaches","searching","pertaining","experiments","introducing","scientific","available","availability","community","significantly","flexibility","companies","improving","generated","attracting","parameterization","regression","distributions","proportional","statistical","maximization","containing","estimation","illustrated","outperforms","biomedical","expectation","likelihood","covariates","properties","parameters","applications","durations","convergence","algorithm","introduce","extensive","therefore","efficient","simulation","inference","assessing","foreground","conditional","precision","contrastive","simulated","alternating","distribution","detecting","direction","structured","anomalies","evolution","covariance","estimated","monitoring","estimating","dependencies","analyzing","structural","changepoints","procedure","graphical","variables","accurately","underlying","probabilistic","contribution","difference","significant","essential","detection","improvement","multipliers","corresponding","penalized","observations","background","perspective","depending","traditional","exceptions","formalism","seemingly","manipulating","classical","characterisation","connecting","operators","monotonic","typically","additional","development","exception","principles","semantics","equivalently","understanding","irreconcilable","foundation","importance","introduces","representation","interpretations","introduced","knowledge","extracted","performed","theoretic","specifying","combining","represented","answering","entailment","implementation","individuals","practical","resolution","formalized","ontologies","usefulness","statements","reasoning","inferences","programming","nonetheless","formalisms","algorithms","consistency","encodings","superiority","combinations","auxiliary","magnitudes","constraints","sensitive","generalized","coefficients","characteristic","preserving","competitive","extension","vocabulary","effective","different","important","pedagogical","previously","difficulty","presenting","motivated","hypothesise","acquisition","curriculum","structure","personalised","environment","ascending","interaction","representations","reinforcement","relations","augmented","relational","interpret","extensions","associated","centrality","expressed","conditioning","specifically","distinguish","numerical","categorical","characterization","resulting","probability","particular","communities","demonstrate","adjustments","empirical","capability","practitioners","separable","generalize","constructed","generalization","illustrative","classification","drastically","optimization","additionally","arbitrarily","construct","increasingly","stochastic","solutions","including","perception","reflecting","preferred","stationary","realistic","measurements","segmented","viewpoints","appearance","alternative","repetition","considers","periodicity","transform","continuities","intrinsic","assumption","divergence","measuring","fundamental","recurrent","perfectly","favorable","repetitive","performing","repetitions","cognition","geometric","statistics","superficial","objective","variations","recognize","topological","benchmark","intelligence","apparently","confidence","interests","challenge","cognitive","surprisingly","supervision","considered","arithmetic","manipul ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	davenport
# 	scientist
# 	nonparametrics
# 	robustify
# 	certificate
# 	proprietary
# 	econometric
# 	factorisation
# 	regularised
# 	readmission
# 	detailing
# 	particulars
# 	biomarker
# 	underpowered
# 	sequentialized
# 	gribonval
# 	exchangeable
# 	exchangeability
# 	accompanies
# 	cumulants
# Some words which never appear in Statistics papers:
# 	ontologies
# 	formalisms
# 	pedagogical
# 	hypothesise
# 	repetition
# 	repetitive
# 	repetitions
# 	apparently
# 	credibility
# 	photographs
# 	illumination
# 	conceived
# 	adjectives
# 	sentential
# 	introductory
# 	transducer
# 	introspective
# 	receptive
# 	compilation
# 	determinism

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061474406073965e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
